# %%
import pandas as pd

# %%
house_data = pd.read_csv('https://raw.githubusercontent.com/zekelabs/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt', index_col='Unnamed: 0')

# %%
house_data.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000

# %%
house_data.shape
# Out:
# (645, 7)

# %%
x = house_data.iloc[:,:-1]
y = house_data.Price

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
xtrain = pd.DataFrame(x_train)
ytrain = pd.DataFrame(y_train)
xtest = pd.DataFrame(x_test)
ytest = pd.DataFrame(y_test)

# %%
import statsmodels.api as sm
model = sm.OLS(ytrain,xtrain)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                     1043.
# Date:                Sat, 06 Jul 2019   Prob (F-statistic):          1.34e-282
# Time:                        12:36:59   Log-Likelihood:                -5830.4
# No. Observations:                 516   AIC:                         1.167e+04
# Df Residuals:                     510   BIC:                         1.170e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Sqft           38.2139      1.814     21.072      0.000      34.651      41.777
# ...

# %%
model = sm.OLS(ytrain,sm.add_constant(xtrain))
results1 = model.fit()

# %%
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     195.6
# Date:                Sat, 06 Jul 2019   Prob (F-statistic):          1.11e-128
# Time:                        12:45:29   Log-Likelihood:                -5830.3
# No. Observations:                 516   AIC:                         1.167e+04
# Df Residuals:                     509   BIC:                         1.170e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1468.5855   4159.842      0.353      0.724   -6703.989    9641.160
# ...

# %%
drop_var = ['TotalFloor','Bedroom','Living.room','Bathroom']
x_new = [var for var in x.columns if var not in drop_var]
x_new= x.iloc[:,:2]
x_new
# Out:
#          Sqft  Floor
# 1    1177.698      2
# 2    2134.800      5
# 3    1138.560      5
# 4    1458.780      2
# 5     967.776     11
# 6    1127.886     11
# 7    1352.040      5
# 8     757.854      5
# 9    1152.792     10
# 10   1423.200      4
# 11    668.904      4
# 12    711.600      4
# 13   1352.040      9
# 14    818.340      4
# 15   2134.800     10
# 16   2768.124      6
# 17    711.600      5
# 18    462.540      5
# 19   2739.660      6
# 20   1174.140      3
# 21   2490.600     19
# 22   2768.124      6
# 23    747.180      7
# 24   1668.702      4
# 25   3664.740     19
# 26   1779.000     10
# 27   3664.740     19
# 28   3059.880     21
# 29    533.700      3
# 30    853.920      6
# ..        ...    ...
# 619  1857.276      2
# 620  1102.980      6
# 621   925.080      2
# 622  2312.700     11
# 623   925.080      4
# 624   711.600      1
# 625  4198.440     15
# 626  3095.460      1
# 627  2590.224      5
# 628  1885.740      8
# 629  1245.300      1
# ...

# %%
#x = x[x_new]

# %%
model = sm.OLS(y,sm.add_constant(x_new))
results1 = model.fit()

# %%
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.698
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     741.1
# Date:                Sat, 06 Jul 2019   Prob (F-statistic):          1.56e-167
# Time:                        13:01:41   Log-Likelihood:                -7289.1
# No. Observations:                 645   AIC:                         1.458e+04
# Df Residuals:                     642   BIC:                         1.460e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2289.9949   1977.443     -1.158      0.247   -6173.032    1593.042
# ...
